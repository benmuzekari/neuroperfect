# %%
# import libraries
import random
import numpy as np
import pandas as pd

# %%
# practice task condition 1 
# create pandas dataframe
practice_task_1_df = pd.DataFrame() 

# generate columns for stim
practice_task_1_df['fractal_60_stim'] = ['stimuli/b1_practice.jpg'] * 10
practice_task_1_df['fractal_80_stim'] = ['stimuli/b2_practice.jpg'] * 10

# randomize stim positions
stim_side = ['left', 'right'] * 1000
fractal_60_side = random.sample(stim_side, 10)
practice_task_1_df['fractal_60_side'] = fractal_60_side
practice_task_1_df.loc[practice_task_1_df.fractal_60_side == 'left', 'fractal_80_side'] = 'right'
practice_task_1_df.loc[practice_task_1_df.fractal_60_side == 'right', 'fractal_80_side'] = 'left'
practice_task_1_df.loc[practice_task_1_df.fractal_60_side == 'left', 'fractal_60_x_pos'] = '-0.27'

stim_y_pos = [0] * 10
practice_task_1_df['fractal_60_y_pos'] = stim_y_pos

practice_task_1_df.loc[practice_task_1_df.fractal_60_side == 'right', 'fractal_60_x_pos'] = '0.27'
practice_task_1_df.loc[practice_task_1_df.fractal_60_side == 'left', 'fractal_80_x_pos'] = '0.27'
practice_task_1_df.loc[practice_task_1_df.fractal_60_side == 'right', 'fractal_80_x_pos'] = '-0.27'
practice_task_1_df['fractal_80_y_pos'] = stim_y_pos

# set bandit probabilities and randomize
fractal_60_reward_list = [1] * 6
fractal_60_no_reward_list = [0] * 4
fractal_60_outcome_list = fractal_60_reward_list + fractal_60_no_reward_list
practice_task_1_df['fractal_60_reward'] = random.sample(fractal_60_outcome_list, len(fractal_60_outcome_list)) 

fractal_80_reward_list = [1] * 8 
fractal_80_no_reward_list = [0] * 2
fractal_80_outcome_list = fractal_80_reward_list + fractal_80_no_reward_list
practice_task_1_df['fractal_80_reward'] = random.sample(fractal_80_outcome_list, len(fractal_80_outcome_list))

# randomize feedback
work_option = ['work_option'] * 2
no_feedback = ['no_feedback'] * 2
veridical_feedback = ['veridical_feedback'] * 6
feedback_outcome_list = work_option + no_feedback + veridical_feedback
practice_task_1_df['feedback_outcome'] = random.sample(feedback_outcome_list, len(feedback_outcome_list))

# %%
# practice task condition 2 
# create pandas dataframe
practice_task_2_df = pd.DataFrame() 

# generate columns for stim
practice_task_2_df['fractal_60_stim'] = ['stimuli/b2_practice.jpg'] * 10
practice_task_2_df['fractal_80_stim'] = ['stimuli/b1_practice.jpg'] * 10

# randomize stim positions
stim_side = ['left', 'right'] * 1000
fractal_60_side = random.sample(stim_side, 10)
practice_task_2_df['fractal_60_side'] = fractal_60_side
practice_task_2_df.loc[practice_task_2_df.fractal_60_side == 'left', 'fractal_80_side'] = 'right'
practice_task_2_df.loc[practice_task_2_df.fractal_60_side == 'right', 'fractal_80_side'] = 'left'
practice_task_2_df.loc[practice_task_2_df.fractal_60_side == 'left', 'fractal_60_x_pos'] = '-0.27'

stim_y_pos = [0] * 10
practice_task_2_df['fractal_60_y_pos'] = stim_y_pos

practice_task_2_df.loc[practice_task_2_df.fractal_60_side == 'right', 'fractal_60_x_pos'] = '0.27'
practice_task_2_df.loc[practice_task_2_df.fractal_60_side == 'left', 'fractal_80_x_pos'] = '0.27'
practice_task_2_df.loc[practice_task_2_df.fractal_60_side == 'right', 'fractal_80_x_pos'] = '-0.27'
practice_task_2_df['fractal_80_y_pos'] = stim_y_pos

# set bandit probabilities and randomize
fractal_60_reward_list = [1] * 6
fractal_60_no_reward_list = [0] * 4
fractal_60_outcome_list = fractal_60_reward_list + fractal_60_no_reward_list
practice_task_2_df['fractal_60_reward'] = random.sample(fractal_60_outcome_list, len(fractal_60_outcome_list)) 

fractal_80_reward_list = [1] * 8 
fractal_80_no_reward_list = [0] * 2
fractal_80_outcome_list = fractal_80_reward_list + fractal_80_no_reward_list
practice_task_2_df['fractal_80_reward'] = random.sample(fractal_80_outcome_list, len(fractal_80_outcome_list))

# randomize feedback
work_option = ['work_option'] * 2
no_feedback = ['no_feedback'] * 2
veridical_feedback = ['veridical_feedback'] * 6
feedback_outcome_list = work_option + no_feedback + veridical_feedback
practice_task_2_df['feedback_outcome'] = random.sample(feedback_outcome_list, len(feedback_outcome_list))

# %%
# main task condition 1 
# create pandas dataframe
main_task_1_df = pd.DataFrame() 

# generate columns for stim
main_task_1_df['fractal_60_stim'] = ['stimuli/fractal_blossom.png'] * 160
main_task_1_df['fractal_80_stim'] = ['stimuli/fractal_octopus.png'] * 160

# # randomize stim positions
stim_side = ['left', 'right'] * 1000
fractal_60_side = random.sample(stim_side, 160)
main_task_1_df['fractal_60_side'] = fractal_60_side
main_task_1_df.loc[main_task_1_df.fractal_60_side == 'left', 'fractal_80_side'] = 'right'
main_task_1_df.loc[main_task_1_df.fractal_60_side == 'right', 'fractal_80_side'] = 'left'
main_task_1_df.loc[main_task_1_df.fractal_60_side == 'left', 'fractal_60_x_pos'] = '-0.27'

stim_y_pos = [0] * 160
main_task_1_df['fractal_60_y_pos'] = stim_y_pos

main_task_1_df.loc[main_task_1_df.fractal_60_side == 'right', 'fractal_60_x_pos'] = '0.27'
main_task_1_df.loc[main_task_1_df.fractal_60_side == 'left', 'fractal_80_x_pos'] = '0.27'
main_task_1_df.loc[main_task_1_df.fractal_60_side == 'right', 'fractal_80_x_pos'] = '-0.27'
main_task_1_df['fractal_80_y_pos'] = stim_y_pos

# set bandit probabilities and randomize
fractal_60_reward_list = [1] * 96
fractal_60_no_reward_list = [0] * 64
fractal_60_outcome_list = fractal_60_reward_list + fractal_60_no_reward_list
main_task_1_df['fractal_60_reward'] = random.sample(fractal_60_outcome_list, len(fractal_60_outcome_list)) 

fractal_80_reward_list = [1] * 128
fractal_80_no_reward_list = [0] * 32
fractal_80_outcome_list = fractal_80_reward_list + fractal_80_no_reward_list
main_task_1_df['fractal_80_reward'] = random.sample(fractal_80_outcome_list, len(fractal_80_outcome_list))

# randomize feedback
work_option = ['work_option'] * 32
no_feedback = ['no_feedback'] * 32
veridical_feedback = ['veridical_feedback'] * 96
feedback_outcome_list = work_option + no_feedback + veridical_feedback
main_task_1_df['feedback_outcome'] = random.sample(feedback_outcome_list, len(feedback_outcome_list))

# %%
# main task condition 2
# create pandas dataframe
main_task_2_df = pd.DataFrame() 

# generate columns for stim
main_task_2_df['fractal_60_stim'] = ['stimuli/fractal_octopus.png'] * 160
main_task_2_df['fractal_80_stim'] = ['stimuli/fractal_blossom.png'] * 160

# randomize stim positions
stim_side = ['left', 'right'] * 1000
fractal_60_side = random.sample(stim_side, 160)
main_task_2_df['fractal_60_side'] = fractal_60_side
main_task_2_df.loc[main_task_2_df.fractal_60_side == 'left', 'fractal_80_side'] = 'right'
main_task_2_df.loc[main_task_2_df.fractal_60_side == 'right', 'fractal_80_side'] = 'left'
main_task_2_df.loc[main_task_2_df.fractal_60_side == 'left', 'fractal_60_x_pos'] = '-0.27'

stim_y_pos = [0] * 160
main_task_2_df['fractal_60_y_pos'] = stim_y_pos

main_task_2_df.loc[main_task_2_df.fractal_60_side == 'right', 'fractal_60_x_pos'] = '0.27'
main_task_2_df.loc[main_task_2_df.fractal_60_side == 'left', 'fractal_80_x_pos'] = '0.27'
main_task_2_df.loc[main_task_2_df.fractal_60_side == 'right', 'fractal_80_x_pos'] = '-0.27'
main_task_2_df['fractal_80_y_pos'] = stim_y_pos

# set bandit probabilities and randomize
fractal_60_reward_list = [1] * 96
fractal_60_no_reward_list = [0] * 64
fractal_60_outcome_list = fractal_60_reward_list + fractal_60_no_reward_list
main_task_2_df['fractal_60_reward'] = random.sample(fractal_60_outcome_list, len(fractal_60_outcome_list)) 

fractal_80_reward_list = [1] * 128
fractal_80_no_reward_list = [0] * 32
fractal_80_outcome_list = fractal_80_reward_list + fractal_80_no_reward_list
main_task_2_df['fractal_80_reward'] = random.sample(fractal_80_outcome_list, len(fractal_80_outcome_list))

# randomize feedback
work_option = ['work_option'] * 32
no_feedback = ['no_feedback'] * 32
veridical_feedback = ['veridical_feedback'] * 96
feedback_outcome_list = work_option + no_feedback + veridical_feedback
main_task_2_df['feedback_outcome'] = random.sample(feedback_outcome_list, len(feedback_outcome_list))

# %%
# pulled from https://github.com/ejolly/psychopy_tools
# randomize practice task ITI 

"""Functions associated with stimulus generation and randomization."""

from __future__ import division
import numpy as np
import pandas as pd

def random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True):
    """
    Create a series of ITIs (in seconds) with a given mean, number of trials and optionally minimum and maximum. ITIs follow either a discrete geometric distribution or a continuous exponential based on user settings. Either way produces a sequence with more shorter ITIs and fewer longer ITIs.
    Perhaps better for fast event-related designs where a mean ITI is desired that comes from a skewed distribution with many shorter ITIs and a few long ITIs.
    *NOTE*: The min ITI is guaranteed, but the max ITI is an upper bound. This means
    the generated maximum may actually be lower than the desired max. Setting the
    maximum too low will result in harder/no solutions and will cause the distribution to be less well behaved.
    Args:
        num_trials (int): number of trials (number of ITIs to create)
        desired_mean (float): desired mean ITI; default 6
        iti_min (int/float): minimum ITI length; guaranteed; default 1
        iti_max (int/float): maximum ITI length; only guaranteed that ITIs will not be longer than this; default None
        discrete (bool): should ITIs be integers only (discrete geometric) or floats (continuous exponential);
            default discrete
        tolerance (float): acceptable difference from desired mean; default 0.05
        nsim (int): number of search iterations; default 10,000
        plot (bool): plot the distribution for visual inspection; default True
    Returns:
        seq (np.ndarray): sequence
    """
    assert isinstance(num_trials,int), "Number of trials must be an integer"

    assert desired_mean > iti_min, "Desired mean must be greater than min ITI!"

    if discrete:
        assert isinstance(iti_min,int), "Minimum ITI from discrete distribution must be an integer"
        if iti_max is not None:
            assert isinstance(iti_max,int), "Maximum ITI from discrete distribution must be an integer"
        else:
            iti_max = np.inf

    # Initialize
    seq_mean = 0
    i = 0
    converged = False

    while not converged:

        # Generate random sequence with desired mean accounting for minimum
        adjusted_mean = desired_mean - (iti_min - 1)
        if discrete:
            # Sampling from geometric distribution where relationship between
            # p param and mean is:
            # mean = 1/p; p = 1/mean
            seq = np.random.geometric(1./adjusted_mean,size=num_trials)
        else:
            # Sampling from exponential distribution where relationship between
            # lambda param and mean is:
            # mean = 1/lambda; lambda = 1/mean; but numpy already uses 1/lambda implicitly
            seq = np.random.exponential(adjusted_mean,size=num_trials)

        seq += iti_min - 1
        seq_mean = seq.mean()

        # Check it
        if (np.allclose(seq_mean,desired_mean,atol=tolerance)) and (seq.max() <= iti_max):
            converged = True
        elif i == nsim:
            break
        else:
            i += 1

    if converged:
        print("Solution found in {} iterations".format(i))
    else:
        print("No solution found after {} interations.\nTry increasing tolerance.".format(nsim))

    if plot:
        if discrete:
            pd.Series(seq).plot(kind='hist',bins=len(np.unique(seq)),xticks=np.arange(iti_min,seq.max()))
        else:
            pd.Series(seq).plot(kind='hist',bins=10,xlim = (iti_min,seq.max()))
    return seq

# %%
practice_task_1_iti_df = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
practice_task_2_iti_df = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
# Out:
# Solution found in 24 iterations
# Solution found in 2 iterations

# %%
# pulled from https://github.com/ejolly/psychopy_tools
# randomize main task ITI 

"""Functions associated with stimulus generation and randomization."""

from __future__ import division
import numpy as np
import pandas as pd

def random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True):
    """
    Create a series of ITIs (in seconds) with a given mean, number of trials and optionally minimum and maximum. ITIs follow either a discrete geometric distribution or a continuous exponential based on user settings. Either way produces a sequence with more shorter ITIs and fewer longer ITIs.
    Perhaps better for fast event-related designs where a mean ITI is desired that comes from a skewed distribution with many shorter ITIs and a few long ITIs.
    *NOTE*: The min ITI is guaranteed, but the max ITI is an upper bound. This means
    the generated maximum may actually be lower than the desired max. Setting the
    maximum too low will result in harder/no solutions and will cause the distribution to be less well behaved.
    Args:
        num_trials (int): number of trials (number of ITIs to create)
        desired_mean (float): desired mean ITI; default 6
        iti_min (int/float): minimum ITI length; guaranteed; default 1
        iti_max (int/float): maximum ITI length; only guaranteed that ITIs will not be longer than this; default None
        discrete (bool): should ITIs be integers only (discrete geometric) or floats (continuous exponential);
            default discrete
        tolerance (float): acceptable difference from desired mean; default 0.05
        nsim (int): number of search iterations; default 10,000
        plot (bool): plot the distribution for visual inspection; default True
    Returns:
        seq (np.ndarray): sequence
    """
    assert isinstance(num_trials,int), "Number of trials must be an integer"

    assert desired_mean > iti_min, "Desired mean must be greater than min ITI!"

    if discrete:
        assert isinstance(iti_min,int), "Minimum ITI from discrete distribution must be an integer"
        if iti_max is not None:
            assert isinstance(iti_max,int), "Maximum ITI from discrete distribution must be an integer"
        else:
            iti_max = np.inf

    # Initialize
    seq_mean = 0
    i = 0
    converged = False

    while not converged:

        # Generate random sequence with desired mean accounting for minimum
        adjusted_mean = desired_mean - (iti_min - 1)
        if discrete:
            # Sampling from geometric distribution where relationship between
            # p param and mean is:
            # mean = 1/p; p = 1/mean
            seq = np.random.geometric(1./adjusted_mean,size=num_trials)
        else:
            # Sampling from exponential distribution where relationship between
            # lambda param and mean is:
            # mean = 1/lambda; lambda = 1/mean; but numpy already uses 1/lambda implicitly
            seq = np.random.exponential(adjusted_mean,size=num_trials)

        seq += iti_min - 1
        seq_mean = seq.mean()

        # Check it
        if (np.allclose(seq_mean,desired_mean,atol=tolerance)) and (seq.max() <= iti_max):
            converged = True
        elif i == nsim:
            break
        else:
            i += 1

    if converged:
        print("Solution found in {} iterations".format(i))
    else:
        print("No solution found after {} interations.\nTry increasing tolerance.".format(nsim))

    if plot:
        if discrete:
            pd.Series(seq).plot(kind='hist',bins=len(np.unique(seq)),xticks=np.arange(iti_min,seq.max()))
        else:
            pd.Series(seq).plot(kind='hist',bins=10,xlim = (iti_min,seq.max()))
    return seq

# %%
# use function in groups of 10 and merge all together (160 trials all at once does not give desired output)
main_task_1_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_2_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_3_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_4_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_5_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_6_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_7_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_8_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_9_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_10_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_11_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_12_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_13_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_14_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_15_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_16_iti = random_jitter(num_trials=10,desired_mean=3,iti_min=2,iti_max=5,discrete=True,tolerance=.05,nsim=20000,plot=True)

# concatenate into one array
main_task_iti_df = np.concatenate((main_task_1_iti, main_task_2_iti,
                                   main_task_3_iti, main_task_4_iti,
                                   main_task_5_iti, main_task_6_iti,
                                   main_task_7_iti, main_task_8_iti,
                                   main_task_9_iti, main_task_10_iti,
                                   main_task_11_iti, main_task_12_iti,
                                   main_task_13_iti, main_task_14_iti,
                                   main_task_15_iti, main_task_16_iti), axis=0, out=None)
# convert to list
main_task_iti_df_list = list(main_task_iti_df)

# shuffle and assign to condition
main_task_1_iti_df = random.sample(main_task_iti_df_list, len(main_task_iti_df_list))
main_task_2_iti_df = random.sample(main_task_iti_df_list, len(main_task_iti_df_list))
# Out:
# Solution found in 14 iterations
# Solution found in 142 iterations
# Solution found in 58 iterations
# Solution found in 39 iterations
# Solution found in 27 iterations
# Solution found in 56 iterations
# Solution found in 4 iterations
# Solution found in 0 iterations
# Solution found in 20 iterations
# Solution found in 2 iterations
# Solution found in 17 iterations
# Solution found in 22 iterations
# Solution found in 10 iterations
# Solution found in 25 iterations
# Solution found in 45 iterations
# Solution found in 13 iterations

# %%
# pulled from https://github.com/ejolly/psychopy_tools
# randomize practice task ISI 

"""Functions associated with stimulus generation and randomization."""

from __future__ import division
import numpy as np
import pandas as pd

def random_jitter(num_trials=10,desired_mean=1.5,iti_min=1,iti_max=3,discrete=True,tolerance=.05,nsim=20000,plot=True):
    """
    Create a series of ITIs (in seconds) with a given mean, number of trials and optionally minimum and maximum. ITIs follow either a discrete geometric distribution or a continuous exponential based on user settings. Either way produces a sequence with more shorter ITIs and fewer longer ITIs.
    Perhaps better for fast event-related designs where a mean ITI is desired that comes from a skewed distribution with many shorter ITIs and a few long ITIs.
    *NOTE*: The min ITI is guaranteed, but the max ITI is an upper bound. This means
    the generated maximum may actually be lower than the desired max. Setting the
    maximum too low will result in harder/no solutions and will cause the distribution to be less well behaved.
    Args:
        num_trials (int): number of trials (number of ITIs to create)
        desired_mean (float): desired mean ITI; default 6
        iti_min (int/float): minimum ITI length; guaranteed; default 1
        iti_max (int/float): maximum ITI length; only guaranteed that ITIs will not be longer than this; default None
        discrete (bool): should ITIs be integers only (discrete geometric) or floats (continuous exponential);
            default discrete
        tolerance (float): acceptable difference from desired mean; default 0.05
        nsim (int): number of search iterations; default 10,000
        plot (bool): plot the distribution for visual inspection; default True
    Returns:
        seq (np.ndarray): sequence
    """
    assert isinstance(num_trials,int), "Number of trials must be an integer"

    assert desired_mean > iti_min, "Desired mean must be greater than min ITI!"

    if discrete:
        assert isinstance(iti_min,int), "Minimum ITI from discrete distribution must be an integer"
        if iti_max is not None:
            assert isinstance(iti_max,int), "Maximum ITI from discrete distribution must be an integer"
        else:
            iti_max = np.inf

    # Initialize
    seq_mean = 0
    i = 0
    converged = False

    while not converged:

        # Generate random sequence with desired mean accounting for minimum
        adjusted_mean = desired_mean - (iti_min - 1)
        if discrete:
            # Sampling from geometric distribution where relationship between
            # p param and mean is:
            # mean = 1/p; p = 1/mean
            seq = np.random.geometric(1./adjusted_mean,size=num_trials)
        else:
            # Sampling from exponential distribution where relationship between
            # lambda param and mean is:
            # mean = 1/lambda; lambda = 1/mean; but numpy already uses 1/lambda implicitly
            seq = np.random.exponential(adjusted_mean,size=num_trials)

        seq += iti_min - 1
        seq_mean = seq.mean()

        # Check it
        if (np.allclose(seq_mean,desired_mean,atol=tolerance)) and (seq.max() <= iti_max):
            converged = True
        elif i == nsim:
            break
        else:
            i += 1

    if converged:
        print("Solution found in {} iterations".format(i))
    else:
        print("No solution found after {} interations.\nTry increasing tolerance.".format(nsim))

    if plot:
        if discrete:
            pd.Series(seq).plot(kind='hist',bins=len(np.unique(seq)),xticks=np.arange(iti_min,seq.max()))
        else:
            pd.Series(seq).plot(kind='hist',bins=10,xlim = (iti_min,seq.max()))
    return seq

# %%
practice_task_1_isi_df = random_jitter(num_trials=10,desired_mean=1.5,iti_min=1,iti_max=3,discrete=True,tolerance=.05,nsim=20000,plot=True)
practice_task_2_isi_df = random_jitter(num_trials=10,desired_mean=1.5,iti_min=1,iti_max=3,discrete=True,tolerance=.05,nsim=20000,plot=True)
# Out:
# Solution found in 3 iterations
# Solution found in 12 iterations

# %%
# pulled from https://github.com/ejolly/psychopy_tools
# randomize main task ISI 

"""Functions associated with stimulus generation and randomization."""

from __future__ import division
import numpy as np
import pandas as pd

def random_jitter(num_trials=160,desired_mean=1.5,iti_min=1,iti_max=3,discrete=True,tolerance=.05,nsim=20000,plot=True):
    """
    Create a series of ITIs (in seconds) with a given mean, number of trials and optionally minimum and maximum. ITIs follow either a discrete geometric distribution or a continuous exponential based on user settings. Either way produces a sequence with more shorter ITIs and fewer longer ITIs.
    Perhaps better for fast event-related designs where a mean ITI is desired that comes from a skewed distribution with many shorter ITIs and a few long ITIs.
    *NOTE*: The min ITI is guaranteed, but the max ITI is an upper bound. This means
    the generated maximum may actually be lower than the desired max. Setting the
    maximum too low will result in harder/no solutions and will cause the distribution to be less well behaved.
    Args:
        num_trials (int): number of trials (number of ITIs to create)
        desired_mean (float): desired mean ITI; default 6
        iti_min (int/float): minimum ITI length; guaranteed; default 1
        iti_max (int/float): maximum ITI length; only guaranteed that ITIs will not be longer than this; default None
        discrete (bool): should ITIs be integers only (discrete geometric) or floats (continuous exponential);
            default discrete
        tolerance (float): acceptable difference from desired mean; default 0.05
        nsim (int): number of search iterations; default 10,000
        plot (bool): plot the distribution for visual inspection; default True
    Returns:
        seq (np.ndarray): sequence
    """
    assert isinstance(num_trials,int), "Number of trials must be an integer"

    assert desired_mean > iti_min, "Desired mean must be greater than min ITI!"

    if discrete:
        assert isinstance(iti_min,int), "Minimum ITI from discrete distribution must be an integer"
        if iti_max is not None:
            assert isinstance(iti_max,int), "Maximum ITI from discrete distribution must be an integer"
        else:
            iti_max = np.inf

    # Initialize
    seq_mean = 0
    i = 0
    converged = False

    while not converged:

        # Generate random sequence with desired mean accounting for minimum
        adjusted_mean = desired_mean - (iti_min - 1)
        if discrete:
            # Sampling from geometric distribution where relationship between
            # p param and mean is:
            # mean = 1/p; p = 1/mean
            seq = np.random.geometric(1./adjusted_mean,size=num_trials)
        else:
            # Sampling from exponential distribution where relationship between
            # lambda param and mean is:
            # mean = 1/lambda; lambda = 1/mean; but numpy already uses 1/lambda implicitly
            seq = np.random.exponential(adjusted_mean,size=num_trials)

        seq += iti_min - 1
        seq_mean = seq.mean()

        # Check it
        if (np.allclose(seq_mean,desired_mean,atol=tolerance)) and (seq.max() <= iti_max):
            converged = True
        elif i == nsim:
            break
        else:
            i += 1

    if converged:
        print("Solution found in {} iterations".format(i))
    else:
        print("No solution found after {} interations.\nTry increasing tolerance.".format(nsim))

    if plot:
        if discrete:
            pd.Series(seq).plot(kind='hist',bins=len(np.unique(seq)),xticks=np.arange(iti_min,seq.max()))
        else:
            pd.Series(seq).plot(kind='hist',bins=10,xlim = (iti_min,seq.max()))
    return seq

# %%
main_task_1_isi_df = random_jitter(num_trials=160,desired_mean=1.5,iti_min=1,iti_max=3,discrete=True,tolerance=.05,nsim=20000,plot=True)
main_task_2_isi_df = random_jitter(num_trials=160,desired_mean=1.5,iti_min=1,iti_max=3,discrete=True,tolerance=.05,nsim=20000,plot=True)
# Out:
# Solution found in 1006 iterations
# Solution found in 5330 iterations

# %%
# write iti's and isi's to df's 
practice_task_1_df['iti'] = practice_task_1_iti_df
practice_task_2_df['iti'] = practice_task_2_iti_df

main_task_1_df['iti'] = main_task_1_iti_df
main_task_2_df['iti'] = main_task_2_iti_df

practice_task_1_df['isi'] = practice_task_1_isi_df
practice_task_2_df['isi'] = practice_task_2_isi_df

main_task_1_df['isi'] = main_task_1_isi_df
main_task_2_df['isi'] = main_task_2_isi_df

# %%
# write dfs to excel file in conditions folder
practice_task_1_df.to_excel("/Users/benmuzekari/Desktop/neuroperfect_task/html/resources/conditions/practice_task_option_1.xlsx", index = False)
practice_task_2_df.to_excel("/Users/benmuzekari/Desktop/neuroperfect_task/html/resources/conditions/practice_task_option_2.xlsx", index = False)
main_task_1_df.to_excel("/Users/benmuzekari/Desktop/neuroperfect_task/html/resources/conditions/main_task_option_1.xlsx", index = False) 
main_task_2_df.to_excel("/Users/benmuzekari/Desktop/neuroperfect_task/html/resources/conditions/main_task_option_2.xlsx", index = False)
